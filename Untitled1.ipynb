# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Custom layer class for DepthwiseConv2D
class CustomDepthwiseConv2D(tf.keras.layers.DepthwiseConv2D):
    @classmethod
    def from_config(cls, config):
        config_copy = config.copy()
        if 'groups' in config_copy:
            del config_copy['groups']
        return cls(**config_copy)

# Load model
def custom_load_model(filepath):
    custom_objects = {
        'DepthwiseConv2D': CustomDepthwiseConv2D
    }
    model = tf.keras.models.load_model(filepath, custom_objects=custom_objects)
    return model

model = custom_load_model("plant_disease_model_mobilenetv2.h5")
print("✅ Model loaded successfully!")
# Out:
# 2025-11-04 16:07:11.964438: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-04 16:07:12.025865: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-04 16:07:15.894219: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-04 16:07:20.971544: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# ✅ Model loaded successfully!

# %%
# Class names
CLASS_NAMES = ['Healthy', 'Powdery', 'Rust']

# Image path
img_path = "leaf.jpg"  # your uploaded image

# Preprocess the image
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# Predict
predictions = model.predict(img_array)
predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = round(100 * np.max(predictions[0]), 2)

print(f"Predicted: {predicted_class} ({confidence}% confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Predicted: Healthy (78.82% confidence)

# %%
# Class names
CLASS_NAMES = ['Healthy', 'Powdery', 'Rust']

# Image path
img_path = "rottenleaf.jpg"  # your uploaded image

# Preprocess the image
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# Predict
predictions = model.predict(img_array)
predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = round(100 * np.max(predictions[0]), 2)

print(f"🌿 Predicted: {predicted_class} ({confidence}% confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 🌿 Predicted: Powdery (56.34% confidence)

# %%
# Class names
CLASS_NAMES = ['Healthy', 'Powdery', 'Rust']

# Image path
img_path = "rottenleaf1.jpg"  # your uploaded image

# Preprocess the image
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# Predict
predictions = model.predict(img_array)
predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = round(100 * np.max(predictions[0]), 2)

print(f"🌿 Predicted: {predicted_class} ({confidence}% confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 🌿 Predicted: Rust (58.34% confidence)

# %%
# Class names
CLASS_NAMES = ['Healthy', 'Powdery', 'Rust']

# Image path
img_path = "rotten1.jpg"  

# Preprocess the image
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# Predict
predictions = model.predict(img_array)
predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = round(100 * np.max(predictions[0]), 2)

print(f"Predicted: {predicted_class} ({confidence}% confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted: Rust (83.88% confidence)

# %%
# Class names
CLASS_NAMES = ['Healthy', 'Powdery', 'Rust']

# Image path
img_path = "rotten2.jpg"  

# Preprocess the image
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# Predict
predictions = model.predict(img_array)
predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = round(100 * np.max(predictions[0]), 2)

print(f"Predicted: {predicted_class} ({confidence}% confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Predicted: Rust (63.07% confidence)

# %%
# Class names
CLASS_NAMES = ['Healthy', 'Powdery', 'Rust']

# Image path
img_path = "rotten3.jpg"  

# Preprocess the image
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# Predict
predictions = model.predict(img_array)
predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = round(100 * np.max(predictions[0]), 2)

print(f"Predicted: {predicted_class} ({confidence}% confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Predicted: Rust (77.57% confidence)

# %%
# Class names
CLASS_NAMES = ['Healthy', 'Powdery', 'Rust']

# Image path
img_path = "rotten4.jpg"  

# Preprocess the image
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# Predict
predictions = model.predict(img_array)
predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = round(100 * np.max(predictions[0]), 2)

print(f"Predicted: {predicted_class} ({confidence}% confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted: Rust (99.88% confidence)
